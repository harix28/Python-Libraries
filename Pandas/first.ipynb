# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas- Series

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index= labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# Dataframe''

# %%
data1 = {
    "Name":['John','Anna','Peter','Linda'],
    "Age":[28,34,29,42],
    "City":['New York', 'Paris', 'Berlin', 'London'],
    "Salary":[65000,70000,62000,85000]
}
df = pd.DataFrame(data1)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
Data2 = [
    ['john',28,'New York', 65000],
    ['Anna',34, 'Paris',70000 ],
    ['Peter',29,'Paris',62000],
    ['Linda',42,'London',85000]
]

columns = ['Name','Age','City','Salary']
df2 = pd.DataFrame(Data2, columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29     Paris   62000
# 3  Linda   42    London   85000

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2       Paris
# 3      London
# Name: City, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   john  New York
# 1   Anna     Paris
# 2  Peter     Paris
# 3  Linda    London

# %% [markdown]
# Creating a Column

# %%
df2["Designation"] =['Doctor','Enginner','Coder','Teacher']

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   john   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Enginner
# 2  Peter   29     Paris   62000       Coder
# 3  Linda   42    London   85000     Teacher

# %%
df2.drop("Designation",axis=1,inplace= False)
df2.drop("Designation",axis=1,inplace= True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29     Paris   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  john   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29     Paris   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Condition Statement/Selection

# %%
# Only Age > 30
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# only Age > 30 , City = Paris
df2[(df2["Age"] > 30) & (df["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
