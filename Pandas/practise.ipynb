# %%
import pandas as pd

# %%
data = {
    "Student_ID": [101, 102, 103, 104, 105, 106],
    "Name": ["Amit", "Neha", "Ravi", "Pooja", "Suresh", "Kiran"],
    "Age": [20, 21, 19, 22, 20, 21],
    "Gender": ["M", "F", "M", "F", "M", "M"],
    "Department": ["CS", "IT", "CS", "EC", "IT", "CS"],
    "Marks": [85, 78, 92, 66, 74, 88],
    "Attendance": [90, 85, 95, 80, 88, 92]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Student_ID    Name  Age Gender Department  Marks  Attendance
# 0         101    Amit   20      M         CS     85          90
# 1         102    Neha   21      F         IT     78          85
# 2         103    Ravi   19      M         CS     92          95
# 3         104   Pooja   22      F         EC     66          80
# 4         105  Suresh   20      M         IT     74          88
# 5         106   Kiran   21      M         CS     88          92

# %%
df.head(3)
# Out:
#    Student_ID  Name  Age Gender Department  Marks  Attendance
# 0         101  Amit   20      M         CS     85          90
# 1         102  Neha   21      F         IT     78          85
# 2         103  Ravi   19      M         CS     92          95

# %%
df.shape
# Out:
# (6, 7)

# %%
df[['Name','Marks']]
# Out:
#      Name  Marks
# 0    Amit     85
# 1    Neha     78
# 2    Ravi     92
# 3   Pooja     66
# 4  Suresh     74
# 5   Kiran     88

# %%
print(df['Marks'].mean())
# Out:
# 80.5

# %%
df['Department'].value_counts()
# Out:
# Department
# CS    3
# IT    2
# EC    1
# Name: count, dtype: int64

# %%
df[df['Marks']>80]['Name']
# Out:
# 0     Amit
# 2     Ravi
# 5    Kiran
# Name: Name, dtype: object

# %%
df[(df['Department']=='CS') & (df['Marks'] >= 80)]
# Out:
#    Student_ID   Name  Age Gender Department  Marks  Attendance
# 0         101   Amit   20      M         CS     85          90
# 2         103   Ravi   19      M         CS     92          95
# 5         106  Kiran   21      M         CS     88          92

# %%
df.sort_values(by='Marks',ascending = False)
# Out:
#    Student_ID    Name  Age Gender Department  Marks  Attendance
# 2         103    Ravi   19      M         CS     92          95
# 5         106   Kiran   21      M         CS     88          92
# 0         101    Amit   20      M         CS     85          90
# 1         102    Neha   21      F         IT     78          85
# 4         105  Suresh   20      M         IT     74          88
# 3         104   Pooja   22      F         EC     66          80

# %%
df['Result'] = df['Marks'].apply(lambda x: "Pass" if x>75 else "Fail")
df
# Out:
#    Student_ID    Name  Age Gender Department  Marks  Attendance Result
# 0         101    Amit   20      M         CS     85          90   Pass
# 1         102    Neha   21      F         IT     78          85   Pass
# 2         103    Ravi   19      M         CS     92          95   Pass
# 3         104   Pooja   22      F         EC     66          80   Fail
# 4         105  Suresh   20      M         IT     74          88   Fail
# 5         106   Kiran   21      M         CS     88          92   Pass

# %%
df['Attendance'].max()
# Out:
# np.int64(95)
